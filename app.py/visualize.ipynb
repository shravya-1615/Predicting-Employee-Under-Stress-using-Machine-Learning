# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_csv('./Dataset/train.csv')
data.describe()
# Out:
#         Designation  Resource Allocation  Mental Fatigue Score     Burn Rate
# count  22750.000000         21369.000000          20633.000000  21626.000000
# mean       2.178725             4.481398              5.728188      0.452005
# std        1.135145             2.047211              1.920839      0.198226
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.600000      0.310000
# 50%        2.000000             4.000000              5.900000      0.450000
# 75%        3.000000             6.000000              7.100000      0.590000
# max        5.000000            10.000000             10.000000      1.000000

# %%
data = data.dropna()
data = data.drop(['Employee ID','Date of Joining'],axis=1,inplace=False)
data['Gender'] = data['Gender'].map({'Male' : 1,'Female' :0})
data['WFH Setup Available'] = data['WFH Setup Available'].map({'Yes':1,'No' : 0})
data['Company Type'] = data['Company Type'].map({'Product':1,'Service' : 0})
data
# Out:
#        Gender  Company Type  WFH Setup Available  Designation  \
# 0           0             0                    0          2.0
# 1           1             0                    1          1.0
# 3           1             0                    1          1.0
# 4           0             0                    0          3.0
# 5           1             1                    1          2.0
# ...       ...           ...                  ...          ...
# 22743       0             1                    1          1.0
# 22744       1             1                    0          3.0
# 22746       0             1                    1          3.0
# 22748       0             0                    0          2.0
# 22749       1             1                    0          3.0
#
#        Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                      3.0                   3.8       0.16
# 1                      2.0                   5.0       0.36
# ...

# %%
sns.set(style='whitegrid')
ax = sns.barplot(x='Burn Rate',y='Gender',data=data)
ax.set_title('Gender vs Burn Rate')
ax.set_xlabel('Burn Rate')
ax.set_ylabel('Gender')
# Out:
# Text(0, 0.5, 'Gender')

# %%
filtered_df = data[(data['Mental Fatigue Score'] >= 0) & (data['Mental Fatigue Score'] <= 10) & (data['Designation'] >= 0) & (data['Designation'] <= 5)]

# plot histogram
g = sns.histplot(data=filtered_df, x='Mental Fatigue Score', hue='Designation', multiple='stack', kde=False, bins=10)
g.set(xlabel='Mental Fatigue Score', ylabel='Number of Instances')
plt.show()

# %%
sns.countplot(data=filtered_df, x='Mental Fatigue Score', hue='Gender')
# Out:
# <AxesSubplot:xlabel='Mental Fatigue Score', ylabel='count'>

# %%
fig = px.bar(data, x='Gender', y='Average Fatigue Score', color='Gender')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 fig = px.bar(data, x='Gender', y='Average Fatigue Score', color='Gender')
#       2 fig.show()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\express\_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     325 def bar(
#     326     data_frame=None,
# ...
